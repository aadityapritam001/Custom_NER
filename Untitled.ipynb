# %%
import pandas as pd

# %%
# df=pd.read_csv('all_data.csv',sep='\t')
# df.to_csv('all_data1.csv',index=False)

# %%
# # from __future__ import print_function
# # import csv
# df1=pd.read_csv('all_data1.csv')
# with open("./all_data2.csv", "w") as f:
#     print(df.columns)
# #     print(df.columns[-1]+',','total\n','.'+',','0',file=f)
# #     print(i.split(',')[0],i.split(',')[-1])

# %%
# from __future__ import print_function
# import csv
# with open('dataset.tsv','w') as f:
#     for i in df1[df1.columns[0]]:
#         ln=len(i.split(',')[-1])
#         ln1=len(i)
#         print(i[0:ln1-ln-1],'\t',i.split(',')[-1].lstrip(),file=f)

# %%
dff=pd.read_csv('dataset.tsv',sep='\t')
dff.columns
# Out:
# Index(['LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR', 'address'], dtype='object')

# %%
dff
# Out:
#      LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR  \
# 0                                                     5
# 1                                                    .
# 2                                       S&Y STATIONERY
# 3                                             05-Jan-17
# 4     NO. 36G JALAN BULAN BM U5/BM, BANDAR PINGGIRAN...
# ...                                                 ...
# 2622                                  AEON CO. (M) BHD
# 2623                                         12-03-2018
# 2624  3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMA...
# 2625                                               42.5
# 2626                                                 .
#
#       address
# 0       total
# 1           O
# 2     company
# 3        date
# 4     address
# ...       ...
# 2622  company
# 2623     date
# 2624  address
# 2625    total
# 2626        O
#
# [2627 rows x 2 columns]

# %%
# from __future__ import print_function
# import csv
# with open('dataset.tsv','w') as f:
#     for i,j in zip(dff['30-04-2018'],dff['date']):
# #         if(i[0]==' ' or i[0]=='  '):
# #             i=i.lstrip()
#         if(i[-1]==' ' or i[-1]=='  '):
#             i=i.rstrip()
#         else:
#             pass
#         print(i,'\t',j,file=f)

# %%
# df=pd.read_csv('dataset.tsv', sep='\t')
# df.to_csv('dataset_wd.tsv',sep='\t',index=None)
dd=pd.read_csv('dataset_wd.tsv', sep='\t')
dd
# Out:
#                       5    total
# 0                    .         0
# 1       S&Y STATIONERY   company
# 2             05-Jan-17     date
# 3                    72    total
# 4                    .         0
# ...                 ...      ...
# 2096                 .         0
# 2097  AEON CO. (M) BHD   company
# 2098         12-03-2018     date
# 2099               42.5    total
# 2100                 .         0
#
# [2101 rows x 2 columns]

# %%
# # from sklearn.utils import shuffle
# # ddff = shuffle(dff)
# # ddff.head(20)
# dd=pd.read_csv('dataset_wd.tsv', sep='\t')
   
# dd=dd[dd.total != 'address']
# dd.to_csv('dataset_wd.tsv',sep='\t', index=None)

# %%
dd=pd.read_csv('d1.tsv', sep='\t')
dd
# Out:
#      LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR  \
# 0                                                     5
# 1                                                    .
# 2                                       S&Y STATIONERY
# 3     NO. 36G JALAN BULAN BM U5/BM, BANDAR PINGGIRAN...
# 4                                                    72
# ...                                                 ...
# 2097                                                 .
# 2098                                  AEON CO. (M) BHD
# 2099  3RD FLR, AEON TAMAN MALURI SC JLN JEJAKA, TAMA...
# 2100                                               42.5
# 2101                                                 .
#
#       address
# 0       total
# 1           O
# 2     company
# 3     address
# 4       total
# ...       ...
# 2097        O
# 2098  company
# 2099  address
# 2100    total
# 2101        O
#
# [2102 rows x 2 columns]

# %%
import json
import logging
import sys
def tsv_to_json_format(input_path,output_path,unknown_label):
    try:
        f=open(input_path,'r') # input file
        fp=open(output_path, 'w') # output file
        data_dict={}
        annotations =[]
        label_dict={}
        s=''
        start=0
        for line in f:
            if line[0:len(line)-1]!='.\tO':
                word,entity=line.split('\t')
                s+=word+" "
                entity=entity[:len(entity)-1]
                if entity!=unknown_label:
                    if len(entity) != 1:
                        d={}
                        d['text']=word
                        d['start']=start
                        d['end']=start+len(word)-1  
                        try:
                            label_dict[entity].append(d)
                        except:
                            label_dict[entity]=[]
                            label_dict[entity].append(d) 
                start+=len(word)+1
        else:
            data_dict['content']=s
            s=''
            label_list=[]
            for ents in list(label_dict.keys()):
                for i in range(len(label_dict[ents])):
                    if(label_dict[ents][i]['text']!=''):
                        l=[ents,label_dict[ents][i]]
                        for j in range(i+1,len(label_dict[ents])): 
                            if(label_dict[ents][i]['text']==label_dict[ents][j]['text']):  
                                di={}
                                di['start']=label_dict[ents][j]['start']
                                di['end']=label_dict[ents][j]['end']
                                di['text']=label_dict[ents][i]['text']
                                l.append(di)
                                label_dict[ents][j]['text']=''
                        label_list.append(l)                          

            for entities in label_list:
                label={}
                label['label']=[entities[0]]
                label['points']=entities[1:]
                annotations.append(label)
            data_dict['annotation']=annotations
            annotations=[]
            json.dump(data_dict, fp)
            fp.write('\n')
            data_dict={}
            start=0
            label_dict={}
    except Exception as e:
        logging.exception("Unable to process file" + "\n" + "error = " + str(e))
        return None

print(tsv_to_json_format("d1.tsv",'d1.json','abc'))
# Out:
# None

# %%
import plac
import logging
import argparse
import sys
import os
import json
import pickle
import spacy

def convert_dataturks_to_spacy(dataturks_JSON_FilePath):
    try:
        training_data = []
        lines=[]
        with open(dataturks_JSON_FilePath, 'r') as f:
            lines = f.readlines()

            for line in lines:
                data = json.loads(line)
                text = data['content']
                entities = []

                for annotation in data['annotation']:

                    point = annotation['points'][0]
                    labels = annotation['label']

                    if not isinstance(labels, list):
                        labels = [labels]

                    for label in labels:
                        entities.append((point['start'], point['end'] + 1 ,label))

                training_data.append((text, {"entities" : entities}))

#             print(training_data)

            with open('spacy.pkl', 'w') as fp:
                pickle.dump(training_data, fp)
            
    except Exception as e:
        logging.exception("Unable to process "+dataturks_JSON_FilePath +"\n"+"error = "+str(e))
        return training_data

convert_dataturks_to_spacy('d1.json')
# Out:
# ERROR:root:Unable to process d1.json
# error = write() argument must be str, not bytes
# Traceback (most recent call last):
#   File "<ipython-input-31-93d539f31947>", line 38, in convert_dataturks_to_spacy
#     pickle.dump(training_data, fp)
# TypeError: write() argument must be str, not bytes
# ...

# %%
TRAIN_DATA = convert_dataturks_to_spacy('d1.json')
for _, annotations in TRAIN_DATA:
#         print([_],[annotations])
         for ent in annotations.get('entities'):
            print(ent[2])
# Out:
# ERROR:root:Unable to process d1.json
# error = write() argument must be str, not bytes
# Traceback (most recent call last):
#   File "<ipython-input-31-93d539f31947>", line 38, in convert_dataturks_to_spacy
#     pickle.dump(training_data, fp)
# TypeError: write() argument must be str, not bytes
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# address
# ...

# %%
import spacy
import random
import h5py
import pickle


TRAIN_DATA = convert_dataturks_to_spacy('d1.json')


def train_spacy(data,iterations):
    TRAIN_DATA = data
    nlp = spacy.blank('en')  # create blank Language class
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner, last=True)
       

    # add labels
    for _, annotations in TRAIN_DATA:
         for ent in annotations.get('entities'):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            print("Statring iteration " + str(itn))
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                nlp.update(
                    [text],  # batch of texts
                    [annotations],  # batch of annotations
                    drop=0.2,  # dropout - make it harder to memorise data
                    sgd=optimizer,  # callable to update weights
                    losses=losses)
            print(losses)
            if(losses['ner']<5 and itn>3000):
                break
            if((itn%1000)==0):
                pickle.dump(nlp, open('MODEL_at'+str(itn), 'wb'))
    return nlp



prdnlp = train_spacy(TRAIN_DATA, 5000)

# Save our trained Model
modelfile = 'Model_d1'
prdnlp.to_disk(modelfile)

#Test your text
test_text = '''
tan chay yee

*** COPY ***
OJC MARKETING SDN BHD
ROC NO: 538358-H
NO 2 &4, JALAN BAYU 4,
BANDAR SERI ALAM,
81750 MASAI, JOHOR
Tel:07-388 2218 Fax:07-388 8218
Email: ng@ojcgroup.com

TAX INVOICE

“Invoice No”: PEGIV-1030765
Date 2 15/01/2019 11:05:16 AM
Cashier : NG CHUAN MIN
Sales Persor : FATIN
Bill To : THE PEAK QUARRY WORKS.

     

Address

__ Description Qty. Price Amount

    

   

‘tal Exclude GST: 193.00
Total GST @6%: 0.00
Total Inclusive GST: 193.00

 

VISA CARD 19;
9900000000004 318

Approval Code:000 V0) .

Goods Sold Are Not Returnable & Refundable
*+*+Thank You. Please Come Again.****'''
doc = prdnlp(test_text)
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, '----->', ent.label_)
# Out:
# ERROR:root:Unable to process d1.json
# error = write() argument must be str, not bytes
# Traceback (most recent call last):
#   File "<ipython-input-31-93d539f31947>", line 38, in convert_dataturks_to_spacy
#     pickle.dump(training_data, fp)
# TypeError: write() argument must be str, not bytes
# C:\Users\Aaditya Raj\AppData\Local\Programs\Python\Python37\lib\site-packages\spacy\language.py:639: UserWarning: [W033] Training a new parser or NER using a model with no lexeme normalization table. This may degrade the performance of the model to some degree. If this is intentional or the language you're using doesn't have a normalization table, please ignore this warning. If this is surprising, make sure you have the spacy-lookups-data package installed. The languages with lexeme normalization tables are currently: da, de, el, en, id, lb, pt, ru, sr, ta, th.
#   **kwargs
# Statring iteration 0
# ...

# %%
import spacy
mod=spacy.load('./Model_d1')
doc=mod("""tan chay yee OJC MARKETING SDN BHD ROC NO: 538358-H NO 2 &4, JALAN BAYU 4, BANDAR SERI ALAM,81750 MASAI, JOHOR Tel:07-388 2218 Fax:07-388 8218 Email: ng@ojcgroup.com TAX INVOICE Date 2 15/01/2019 11:05:16 AM Cashier : NG CHUAN MIN ‘tal Exclude GST: 193.00 Total GST @6%: 0.00 Total Inclusive GST: 193.00 """)
for ent in doc.ents:
        print(ent.text,'------->',ent.label_)
# Out:
# tan chay yee OJC MARKETING SDN BHD ROC NO: 538358-H NO 2 &4, JALAN BAYU 4, BANDAR SERI ALAM,81750 MASAI, JOHOR Tel:07-388 2218 Fax:07-388 8218 Email: ng@ojcgroup.com TAX INVOICE Date 2 15/01/2019 11:05:16 AM Cashier : NG CHUAN MIN ‘tal Exclude GST: -------> address
# 193.00 -------> total
# 193.00 -------> total

# %%
var="""tan chay yee OJC MARKETING SDN BHD ROC NO: 538358-H NO 2 &4, JALAN BAYU 4, BANDAR SERI ALAM,81750 MASAI, JOHOR Tel:07-388 2218 Fax:07-388 8218 Email: ng@ojcgroup.com TAX INVOICE Date 2 15/01/2019 11:05:16 AM Cashier : NG CHUAN MIN ‘tal Exclude GST: 193.00 Total GST @6%: 0.00 Total Inclusive GST: 193.00
"""

# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract

pytesseract.pytesseract.tesseract_cmd="C:\\Program Files\\Tesseract-OCR\\tesseract.exe"

def ocr_core(filename):
    """
    This function will handle the core OCR processing of images.
    """
    
    text = pytesseract.image_to_string(Image.open(filename))  # We'll use Pillow's Image class to open the image and pytesseract to detect the string in the image
    return text
text=ocr_core('test/X00016469620.jpg')

# %%
var="""tan chay yee OJC MARKETING SDN BHD ROC NO: 538358-H NO 2 &4, JALAN BAYU 4, BANDAR SERI ALAM,81750 MASAI, JOHOR Tel:07-388 2218 Fax:07-388 8218 Email: ng@ojcgroup.com TAX INVOICE Date 2 15/01/2019 11:05:16 AM Cashier : NG CHUAN MIN ‘tal Exclude GST: 193.00 Total GST @6%: 0.00 Total Inclusive GST: 193.00
"""

# %%
from spacy import displacy
# from test_ref import *

nlp = pickle.load(open("Model_at2000",'rb'))
doc1=nlp(var)

displacy.serve(doc1, style="ent")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">tan chay yee OJC MARKETING SDN BHD ROC NO: 538358-H
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NO 2 &amp;4, JALAN BAYU 4, BANDAR SERI ALAM,81750 MASAI, JOHOR Tel:07-388 2218 Fax:07-388 8218
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">address</span>
# </mark>
# ...

# %%
import spacy
from spacy import displacy
# from test_ref import *

nlp = spacy.load("Model_d1")
doc1=nlp(var)

displacy.serve(doc1, style="ent")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tan chay yee OJC MARKETING SDN BHD ROC NO: 538358-H NO 2 &amp;4, JALAN BAYU 4, BANDAR SERI ALAM,81750 MASAI, JOHOR Tel:07-388 2218 Fax:07-388 8218 Email: ng@ojcgroup.com TAX INVOICE Date 2 15/01/2019 11:05:16 AM Cashier : NG CHUAN MIN ‘tal Exclude GST:
# ...

# %% [markdown]
# # ------------------------------------2nd-----------------------------------

# %%
import pandas as pd
dd=pd.read_csv('spaces.csv')
dd.to_csv('spaces.tsv',sep='\t',index=None)
df=pd.read_csv('spaces.tsv', sep='\t')
df
# Out:
#     LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR  \
# 0                                                    5
# 1                                                   .
# 2                                                  NaN
# 3                                      S&Y STATIONERY
# 4    NO. 36G JALAN BULAN BM U5/BM, BANDAR PINGGIRAN...
# ..                                                 ...
# 797                                                NaN
# 798                       SYARIKAT PERNIAGAAN GIN KEE
# 799  NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA...
# 800                                              39.75
# 801                                                 .
#
#      address
# 0      total
# 1          O
# 2        NaN
# 3    company
# 4    address
# ..       ...
# 797      NaN
# 798  company
# 799  address
# 800    total
# 801        O
#
# [802 rows x 2 columns]

# %%
def load_data_spacy(file_path):
    ''' Converts data from:
    word \t label \n word \t label \n \n word \t label
    to: sentence, {entities : [(start, end, label), (stard, end, label)]}
    '''
    file = open(file_path, 'r')
    training_data, entities, sentence, unique_labels = [], [], [], []
    current_annotation = None
    start =0
    end = 0 # initialize counter to keep track of start and end characters
    for line in file:
        line = line.strip("\n").split("\t")
        # lines with len > 1 are words
        if len(line) > 1:
            label = line[1]
            if(label != 'O'):
                label = line[1]     # the .txt is formatted: label \t word, label[0:2] = label_type
            #label_type = line[0][0] # beginning of annotations - "B", intermediate - "I"
            word = line[0]
            sentence.append(word)
            start = end
            end += (len(word) + 1)  # length of the word + trailing space
           
            if label == 'company' :  # if at the end of an annotation
                entities.append(( start,end-1, label))  # append the annotation
                              
            if label == 'address':                         # if beginning new annotation
                entities.append(( start,end-1, label))# start annotation at beginning of word
                
            if label == 'total':                         # if beginning new annotation
                entities.append(( start,end-1, label))
           
            if label != 'O' and label not in unique_labels:
                unique_labels.append(label)
 
        # lines with len == 1 are breaks between sentences
        if len(line) == 2:
            if(len(entities) > 0):
                sentence = " ".join(sentence)
                training_data.append([sentence, {'entities' : entities}])
            # reset the counters and temporary lists
            end = 0 
            start = 0
            entities, sentence = [], []
            
    file.close()
    return training_data, unique_labels

load_data_spacy('spaces.tsv')
# Out:
# ([['LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR',
#    {'entities': [(0, 96, 'address')]}],
#   ['5', {'entities': [(0, 1, 'total')]}],
#   ['S&Y STATIONERY ', {'entities': [(0, 15, 'company')]}],
#   ['NO. 36G JALAN BULAN BM U5/BM, BANDAR PINGGIRAN SUBANG, SEKSYEN U5, 40150 SHAH ALAM, SELANGOR.',
#    {'entities': [(0, 93, 'address')]}],
#   ['72', {'entities': [(0, 2, 'total')]}],
#   ['99 SPEED MART S/B ', {'entities': [(0, 18, 'company')]}],
#   ['LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY 41150 KLANG, SELANGOR',
#    {'entities': [(0, 64, 'address')]}],
#   ['37.45', {'entities': [(0, 5, 'total')]}],
#   ['ENW HARDWARE CENTRE (M) SDN. BHD. ', {'entities': [(0, 34, 'company')]}],
#   ['NO: G3, BLK G, JLN PJU 1A/3, ARA DAMANSARA, 47301 PETALING JAYA, SELANGOR DARUL EHSAN.',
#    {'entities': [(0, 86, 'address')]}],
#   ['27', {'entities': [(0, 2, 'total')]}],
# ...

# %%
import json
import logging
import sys
def tsv_to_json_format(input_path,output_path,unknown_label):
    try:
        f=open(input_path,'r') # input file
        fp=open(output_path, 'w') # output file
        data_dict={}
        annotations =[]
        label_dict={}
        s=''
        start=0
        for line in f:
            if line[0:len(line)-1]!='.\t0':
                word,entity=line.split('\t')
                s+=word+" "
                entity=entity[:len(entity)-1]
                if entity!=unknown_label:
                    if len(entity) != 1:
                        d={}
                        d['text']=word
                        d['start']=start
                        d['end']=start+len(word)-1  
                        try:
                            label_dict[entity].append(d)
                        except:
                            label_dict[entity]=[]
                            label_dict[entity].append(d) 
                start+=len(word)+1
        else:
            data_dict['content']=s
            s=''
            label_list=[]
            for ents in list(label_dict.keys()):
                for i in range(len(label_dict[ents])):
                    if(label_dict[ents][i]['text']!=''):
                        l=[ents,label_dict[ents][i]]
                        for j in range(i+1,len(label_dict[ents])): 
                            if(label_dict[ents][i]['text']==label_dict[ents][j]['text']):  
                                di={}
                                di['start']=label_dict[ents][j]['start']
                                di['end']=label_dict[ents][j]['end']
                                di['text']=label_dict[ents][i]['text']
                                l.append(di)
                                label_dict[ents][j]['text']=''
                        label_list.append(l)                          

            for entities in label_list:
                label={}
                label['label']=[entities[0]]
                label['points']=entities[1:]
                annotations.append(label)
            data_dict['annotation']=annotations
            annotations=[]
            json.dump(data_dict, fp)
            fp.write('\n')
            data_dict={}
            start=0
            label_dict={}
    except Exception as e:
        logging.exception("Unable to process file" + "\n" + "error = " + str(e))
        return None

print(tsv_to_json_format("spaces.tsv",'spaces.json','abc'))
# Out:
# None

# %%
import plac
import logging
import argparse
import sys
import os
import json
import pickle
import spacy

def convert_dataturks_to_spacy(dataturks_JSON_FilePath):
    try:
        training_data = []
        lines=[]
        with open(dataturks_JSON_FilePath, 'r') as f:
            lines = f.readlines()

            for line in lines:
                data = json.loads(line)
                text = data['content']
                entities = []

                for annotation in data['annotation']:

                    point = annotation['points'][0]
                    labels = annotation['label']

                    if not isinstance(labels, list):
                        labels = [labels]

                    for label in labels:
                        entities.append((point['start'], point['end'] + 1 ,label))

                training_data.append((text, {"entities" : entities}))

#             print(training_data)

            with open('spacy.pkl', 'w') as fp:
                pickle.dump(training_data, fp)
            
    except Exception as e:
        logging.exception("Unable to process "+dataturks_JSON_FilePath +"\n"+"error = "+str(e))
        return training_data

convert_dataturks_to_spacy('spaces.json')
# Out:
# ERROR:root:Unable to process spaces.json
# error = write() argument must be str, not bytes
# Traceback (most recent call last):
#   File "<ipython-input-93-89993b21883b>", line 38, in convert_dataturks_to_spacy
#     pickle.dump(training_data, fp)
# TypeError: write() argument must be str, not bytes
# ...

# %%
import spacy
import random
import h5py
import pickle


TRAIN_DATA = convert_dataturks_to_spacy('spaces.json')


def train_spacy(data,iterations):
    TRAIN_DATA = data
    nlp = spacy.blank('en')  # create blank Language class
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner, last=True)
       

    # add labels
    for _, annotations in TRAIN_DATA:
         for ent in annotations.get('entities'):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            print("Statring iteration " + str(itn))
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                nlp.update(
                    [text],  # batch of texts
                    [annotations],  # batch of annotations
                    drop=0.2,  # dropout - make it harder to memorise data
                    sgd=optimizer,  # callable to update weights
                    losses=losses)
            print(losses)
            if(losses['ner']<5 and itn>3000):
                break
            if((itn%1000)==0):
                pickle.dump(nlp, open('MODEL_at'+str(itn), 'wb'))
    return nlp



prdnlp = train_spacy(TRAIN_DATA, 500)

# Save our trained Model
modelfile = 'Model_spaces'
prdnlp.to_disk(modelfile)

#Test your text
test_text = '''
tan chay yee

*** COPY ***
OJC MARKETING SDN BHD
ROC NO: 538358-H
NO 2 &4, JALAN BAYU 4,
BANDAR SERI ALAM,
81750 MASAI, JOHOR
Tel:07-388 2218 Fax:07-388 8218
Email: ng@ojcgroup.com

TAX INVOICE

“Invoice No”: PEGIV-1030765
Date 2 15/01/2019 11:05:16 AM
Cashier : NG CHUAN MIN
Sales Persor : FATIN
Bill To : THE PEAK QUARRY WORKS.

     

Address

__ Description Qty. Price Amount

    

   

‘tal Exclude GST: 193.00
Total GST @6%: 0.00
Total Inclusive GST: 193.00

 

VISA CARD 19;
9900000000004 318

Approval Code:000 V0) .

Goods Sold Are Not Returnable & Refundable
*+*+Thank You. Please Come Again.****'''
doc = prdnlp(test_text)
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, '----->', ent.label_)
# Out:
# ERROR:root:Unable to process spaces.json
# error = write() argument must be str, not bytes
# Traceback (most recent call last):
#   File "<ipython-input-80-89993b21883b>", line 38, in convert_dataturks_to_spacy
#     pickle.dump(training_data, fp)
# TypeError: write() argument must be str, not bytes
# Statring iteration 0
# {'ner': 3233.5711822509766}
# Statring iteration 1
# {'ner': 3131.02188873291}
# Statring iteration 2
# {'ner': 3067.498149871826}
# Statring iteration 3
# {'ner': 2787.482006072998}
# Statring iteration 4
# {'ner': 2558.5577850341797}
# Statring iteration 5
# {'ner': 1882.9865798950195}
# Statring iteration 6
# {'ner': 1370.1669807434082}
# Statring iteration 7
# {'ner': 1377.817512512207}
# Statring iteration 8
# {'ner': 1384.3572444915771}
# Statring iteration 9
# {'ner': 1554.833574295044}
# Statring iteration 10
# {'ner': 1404.8965129852295}
# Statring iteration 11
# {'ner': 1296.4479494094849}
# Statring iteration 12
# {'ner': 935.4626331329346}
# ...

# %%
text='''LIGHTROOM GALLERY SDN BHD
No: 28, TALAN ASTANA 1C
BANDAR LUKIT RAJA, 41050

KLANG SELANGOR D.E, MALAYSIA
ROC No. : (1072825-A)
GST No. : 000584089600
Tel:03-3362 4395 Fax:03-3362 4395

CREDIT NOTE
Station: CASHIER C/N No: LCNO0212
Cashier: ANGELA Cover : 1
Bill Date : 20/11/2017
Bill Start: 20/11/2017 03:57:01 PM

Code : 300-E0009

Name : ESWARAN 012-6369400

Address

GST No.

YT51129 SR

YE36 BK 12W WW LED TRACK LIGHT
-2  * RM 45.29 UNI ( 5.43)=RM 90. 57

YT52683 SR

YE44 35W WW BK TRACK HOLDER

1 * RM 155.66 UNI ( 9,34)=RM 155. 66

CH50688 SR

IMETER TRACK-BK

1 * RM 16.99 UNI ( 1.01)=RM 16. 7%

= SR
RM39. 80 CONTRA W LCNOO211

0 * UNIT

Sub Total : RM 263.02
Item Discount 5 i RM 0720
Service Charge : RM 0), 00
GST/TAX 6% : RM 15. 78
TOT’ : RM 278.80

CAS1, : RM 278.80
CHANGE: RM 0. 00

Ttem Count: 4
Qty Count : 4.0

Closed Bill: 20/11/2017 04:01:23 PM

You, Please come again.
Tene Sold are not refundable, returnable
BANK ACC MBB 5128 4851 2118
BANK ACC MBB 5626 4732 1744
BANK ACC AMBANK 888 100 123 3706

GST Summary Amount (RM) Tax (RM)

‘ 5. 78
SR @ 6% 263, 02 15
ZR/0S/EZ 0. 00 0. 00'''

# %%
import spacy
from spacy import displacy
# from test_ref import *

nlp = spacy.load("Model_spaces")
doc1=nlp(text)

displacy.serve(doc1, style="ent")
# Out:
# C:\Users\Aaditya Raj\AppData\Local\Programs\Python\Python37\lib\site-packages\spacy\displacy\__init__.py:94: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">LIGHTROOM GALLERY SDN BHD</br>
# ...

# %% [markdown]
# #  ------------------Combining Date Regex + NER ------------------------

# %%
text1="""tan chay yee OJC MARKETING SDN BHD ROC NO: 538358-H NO 2 &4, JALAN BAYU 4, BANDAR SERI ALAM,81750 MASAI, JOHOR Tel:07-388 2218 Fax:07-388 8218 Email: ng@ojcgroup.com TAX INVOICE Date 2 15/01/2019 11:05:16 AM Cashier : NG CHUAN MIN ‘tal Exclude GST: 193.00 Total GST @6%: 0.00 Total Inclusive GST: 193.00
"""
text2="""WR ee Ro Dyer 5:

UROKO JAPANESE CUISINE SDN BHD
22A-1, JALAN 17/54,
SECTION 17,
46400 PETALING JAYA,
SELANGOR.
03-7932 1023/0191
GST Reg No; 001126838272

Bill No : O1H-25029
Date : 20/03/2018 6:41:02 PM
Cashier : RESAN
Table No : $09
Qty Description Amount
1 KO NABE INANIWA 24.00 SR
UBON @ 24.00
1 GREEN TEA @ 1.00 1.00 SR
1 GYOZA Specs @ 15.00 15.00 SR
1 GARLIC CHAHAN @ (T 6.00 SR
A
“40 7 Total 7 ~~ -46.00
Discount : (.00)
service Chg 10.00% : 4.00
GST: 3.00
Grand Total: 53.00
Net Total : 53.00

GST Summary % Amount(RM Tax(RM) M
SR 6.00 60.00 3.00
.	.	O

TEO HENG STATIONER

(001g ya
NO. 53, JALAN BESAR, 45500 BATA!

ELANGOR DARULCEHSA

 
    

CASH D

Receipt No.: ©S1801/27175 Wate: 27/01/2018

 

7 a AMOUNT
ITEM Qty UP Discs “esp

 

4355 1 3.96 4,09 3.80 *
~ DOUBLE SIDE FOAM TAPE 18MM

9557950605126 5 274 4.96 13.00 +
- CAMIS SQ BOOK 200

9557369315028 1 5.47 496 5.20 «
~ EAGLE F4 200 FOOLSCAP BOOK

9557369305006 1 3.96 409 3.80 «

~ EAGLE F4 120 NUMBERING FOOLSCAP
BOOK

 

Total Qty. : 8 25,80

 

SUB-TOTAL (EX) : 25.80
TOTAL TAX 1.55
ROUNDING : 0.00
TOTAL : 27.35
CASH : 27.35
CHANGE : 0.00"""

# %%
from spacy import displacy
import re

dp=['\d\d\s(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)\s\d{4}','([1-9]|1[0-9]|2[0-9]|3[0-1]|0[0-9])(.|-|\/)([1-9]|1[0-2]|0[0-9])(.|-|\/)(20[0-9][0-9])','([1-9]|1[0-9]|2[0-9]|3[0-1]|0[0-9])(-)(Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)(-)(20[0-9][0-9])']
match=[]
mod=spacy.load('./Model_d1')
doc=mod(text)
for ent in doc.ents:
        print(ent.text,'------->',ent.label_)
for i in dp:
    match += re.findall(i,text)
    
print('Date------->',[''.join(match[x]) for x in range(len(match))])
# Out:
# tan chay yee OJC MARKETING SDN BHD ROC NO: 538358-H NO 2 &4, JALAN BAYU 4, BANDAR SERI ALAM,81750 MASAI, JOHOR Tel:07-388 2218 Fax:07-388 8218 Email: ng@ojcgroup.com TAX INVOICE Date 2 15/01/2019 11:05:16 AM Cashier : NG CHUAN MIN ‘tal Exclude GST: -------> address
# 193.00 -------> total
# 193.00 -------> total
# Date-------> ['15/01/2019']

# %%
from spacy import displacy
import re

dp=['\d\d\s(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)\s\d{4}','([1-9]|1[0-9]|2[0-9]|3[0-1]|0[0-9])(.|-|\/)([1-9]|1[0-2]|0[0-9])(.|-|\/)(20[0-9][0-9])','([1-9]|1[0-9]|2[0-9]|3[0-1]|0[0-9])(-)(Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)(-)(20[0-9][0-9])']
match=[]
mod=spacy.load('./Model_d1')
doc=mod(text2)
for ent in doc.ents:
        print(ent.text,'------->',ent.label_)
for i in dp:
    match += re.findall(i,text2)
    
print('Date------->',[''.join(match[x]) for x in range(len(match))])
# Out:
# WR ee Ro Dyer 5:
#
# UROKO JAPANESE CUISINE SDN BHD
# 22A-1, JALAN 17/54,
# SECTION 17,
# 46400 PETALING JAYA,
# SELANGOR.
# 03-7932 1023/0191
# GST Reg No; 001126838272
#
# Bill No : O1H-25029
# Date : 20/03/2018 6:41:02 PM
# Cashier : RESAN
# Table No : $09
# Qty Description Amount
# 1 KO NABE INANIWA 24.00 SR
# UBON @ 24.00
# 1 GREEN TEA @ 1.00 1.00 SR
# 1 GYOZA Specs @ 15.00 15.00 SR
# 1 GARLIC CHAHAN @ (T 6.00 SR
# A
# “40 7 Total 7 ~~ -46.00
# Discount : (.00)
# service Chg 10.00% : 4.00
# GST: 3.00
# Grand Total: -------> address
# 53.00 -------> total
# 53.00 -------> total
# 6.00 -------> total
# 3.00 -------> total
# 9557369315028 -------> total
# 3.96 -------> total
# 1.55 -------> total
# 27.35 -------> total
# 27.35 -------> total
# 0.00 -------> total
# Date-------> ['20/03/2018', '27/01/2018']

# %%
from spacy import displacy
# from test_ref import *

nlp = pickle.load(open("Model_at2000",'rb'))
doc1=nlp(text)

displacy.serve(doc1, style="ent")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">tan chay yee OJC MARKETING SDN BHD ROC NO: 538358-H
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NO 2 &amp;4, JALAN BAYU 4, BANDAR SERI ALAM,81750 MASAI, JOHOR Tel:07-388 2218 Fax:07-388 8218
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">address</span>
# </mark>
# ...

# %%
from spacy import displacy
# from test_ref import *

nlp = pickle.load(open("Model_at2000",'rb'))
doc1=nlp(text2)

displacy.serve(doc1, style="ent")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-104-7b84fa455c0e> in <module>
#       2 # from test_ref import *
#       3
# ----> 4 nlp = pickle.load(open("Model_d1",'rb'))
#       5 doc1=nlp(text2)
#       6
#
# PermissionError: [Errno 13] Permission denied: 'Model_d1'
